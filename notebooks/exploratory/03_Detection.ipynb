# %% [markdown]
# # Object Detection on Images
# https://github.com/ultralytics/yolov5/issues/36

# %%
import torch
import cv2
import os
import pandas as pd

# %%
img_dir = "./img/"

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/sam/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-6-3 Python-3.10.5 torch-1.11.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1070, 8120MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
imgs = []
for filename in os.listdir(img_dir):
    img = cv2.imread(os.path.join(img_dir, filename))
    if img is not None:
        imgs.append(img)

# %%
results = model(imgs)

# %%
type(results.pandas().xyxy[0])
# Out:
# pandas.core.frame.DataFrame

# %%
frame_count = len(results.pandas())
#df = pd.concat([results.pandas().xyxy[frame].insert(0, 'Frame', frame) for frame in range(frame_count)])
df = pd.DataFrame()
for frame in range(frame_count):
    f = results.pandas().xyxy[frame]
    f.insert(0, "Frame", frame)
    df = pd.concat([df, f])

# %%
df
# Out:
#    Frame         xmin        ymin         xmax        ymax  confidence  class  \
# 0      0  1433.706421  488.719940  1708.840576  740.162964    0.827890     33
# 0      1  1031.257812  569.863159  1271.746826  815.656494    0.893737     33
# 0      2   928.532715  583.397888  1164.354614  825.896301    0.861772     33
# 0      3  1293.269653  527.327881  1553.011963  774.657837    0.736348     33
# 1      3  1294.368530  524.898376  1552.225830  775.670410    0.608777     32
# 0      4  1331.571045  518.017822  1593.505859  765.923035    0.863658     33
# 0      5  1464.015015  481.017792  1738.431885  730.924927    0.821360     33
# 1      5  1465.299805  480.114532  1742.131592  732.316406    0.521903     32
# 0      6  1078.803711  564.970947  1322.641724  811.090759    0.835558     33
# 0      7  1172.937256  555.015625  1421.593750  796.946289    0.758928     33
# 1      7  1174.555420  547.615845  1415.317139  796.176819    0.450545     32
# 0      8  1452.440674  484.956940  1726.366699  737.713806    0.887129     33
# 0      9  1388.661377  502.665436  1659.169678  752.241333    0.857470     33
# 0     10  1215.415649  541.291016  1471.453857  788.255493    0.711530     33
# 0     11  1361.310791  510.005554  1628.179321  758.311340    0.867005     33
# 0     12  1129.460815  559.554688  1373.805176  804.623047    0.832937     33
# 1     12  1130.040283  554.508667  1366.066895  805.393066    0.353374     32
# 0     13  1256.074219  535.424194  1513.749023  782.093018    0.797956     33
# 0     14  1471.962646  477.574219  1745.412842  729.225220    0.907878     33
# 0     15   822.696045  588.186157  1059.211182  826.966553    0.827122     33
# 0     16   769.718445  589.711182  1003.286499  828.855469    0.886371     33
# 0     17   875.306519  582.866211  1113.175659  824.529419    0.889890     33
# 0     18  1417.407959  496.269348  1685.420410  747.159912    0.895420     33
# 0     19   978.588501  576.717896  1217.104980  822.489014    0.876464     33
#
#           name
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 1  sports ball
# 0         kite
# 0         kite
# 1  sports ball
# 0         kite
# 0         kite
# 1  sports ball
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 1  sports ball
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 0         kite
# 0         kite
